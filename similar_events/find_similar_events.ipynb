# %%
import pandas as pd
import numpy as np

import jieba
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
import re

import warnings
warnings.filterwarnings('ignore')

# %%
kalshi_data = pd.read_csv('../kalshi/data_events.csv')
poly_data = pd.read_csv('../polymarket/markets_data.csv')

# %%
kalshi_titles = kalshi_data['title'].values
kalshi_titles
# Out:
# array(['Initial jobless claims from Aug 22-28, 2021?',
#        'EU meets its 2030 climate goals?',
#        'India meets its 2030 climate goals?', ...,
#        'New home sales in July 2021?',
#        'COVID daily cases on July 26, 2021?',
#        'NYC subway riders from Jul 26-Aug 1, 2021?'], dtype=object)

# %%
poly_questions = poly_data['question'].values
poly_questions
# Out:
# array(['NFL Saturday: Chiefs vs. Raiders',
#        'archWill Kamala Harris win the 2024 US Presidential Election?',
#        'Will the Nuggets be the 2022-23 NBA Champion?', ...,
#        'Will Jake Paul fight Person A next?', 'Cowboys vs. Commanders',
#        'Will $POPCAT be listed first on Binance?'], dtype=object)

# %% [markdown]
# # question相似度计算

# %%
# 对文本分词后，再去除停用词
def wordCutter(text, stop_file_path):
    # 自定义词典
    jieba.load_userdict(stop_file_path) # 加载停用词
    # 将 jieba 进行初始化
    jieba.initialize()
    # 文本预处理：去除标点符号
    textSymbolDeleted = re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]', '', text)
    # 文本分词
    listExactSeparated = textSymbolDeleted.split(' ')
    listExactSeparated = [x.lower() for x in listExactSeparated]  # 换成小写
    listResult = []
    # 读取停用词库
    with open(stop_file_path, encoding='utf-8') as f:
        cons = f.readlines()
        setStopwords = set()
        for stopword in cons:
            # 去掉读取每一行数据的\n
            stopword = stopword.replace("\n", "")
            stopword = stopword.replace(" ", "")
            setStopwords.add(stopword)
    
    # 去除停用词
    for word in listExactSeparated:
        if word not in setStopwords:
            listResult.append(word)
    return ','.join(listResult)

# %%
stop_file_path='常用英文停用词(NLP处理英文必备)stopwords.txt'
# poly_questions 
poly_question_words=[wordCutter(x,stop_file_path) for x in poly_questions]
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\PuLin\AppData\Local\Temp\jieba.cache
# Loading model cost 0.918 seconds.
# Prefix dict has been built successfully.

# %%
poly_question_words[:3]
# Out:
# ['nfl,saturday,chiefs,raiders',
#  'archwill,kamala,harris,win,2024,presidential,election',
#  'nuggets,202223,nba,champion']

# %%
# kalshi_titles
kalshi_title_words=[wordCutter(x,stop_file_path)for x in kalshi_titles]

# %%
kalshi_title_words[:3]
# Out:
# ['initial,jobless,claims,aug,2228,2021',
#  'eu,meets,2030,climate,goals',
#  'india,meets,2030,climate,goals']

# %%
# 提取TFIDF
tfidf = TfidfVectorizer()
tfidf.fit(poly_question_words + kalshi_title_words)
poly_feat = tfidf.transform(poly_question_words) # 转化为矩阵
kalshi_feat = tfidf.transform(kalshi_title_words)

# %%
# 进行归一化，为后面进行相似度计算做准备
poly_feat = normalize(poly_feat)
kalshi_feat = normalize(kalshi_feat)

# %%
# 检索进行排序
poly_kalshi_scores = pd.DataFrame()
for query_idx, feat in enumerate(poly_feat):
    # 对poly的每个question 与 每kalshi的每个question计算TFIDF相似度
    score = feat @ kalshi_feat.T
    score = score.toarray()[0]
    max_score_page_idx = score.argmax()  # 找到TFIDF值最大的index
    poly_kalshi_scores.loc[query_idx,'poly_index'] = query_idx
    poly_kalshi_scores.loc[query_idx,'poly_question'] = poly_data.loc[query_idx,'question']
    poly_kalshi_scores.loc[query_idx,'poly_question_id'] = poly_data.loc[query_idx,'question_id']

    poly_kalshi_scores.loc[query_idx,'kalshi_index'] = max_score_page_idx
    poly_kalshi_scores.loc[query_idx,'kalshi_title'] = kalshi_data.loc[max_score_page_idx,'title']
    poly_kalshi_scores.loc[query_idx,'kalshi_event_ticker'] = kalshi_data.loc[max_score_page_idx,'event_ticker']
    poly_kalshi_scores.loc[query_idx,'kalshi_series_ticker'] = kalshi_data.loc[max_score_page_idx,'series_ticker']

    poly_kalshi_scores.loc[query_idx,'max_score'] = max(score)

    # 再加每个事件的开始和结束事件

# %%
poly_kalshi_scores = poly_kalshi_scores.sort_values(by='max_score',ascending=False)

# %%
poly_kalshi_scores.to_csv('poly_kalshi_scores.csv',index=False)

# %%
# 保留得分大于0.98的数据
remain_poly_kalshi = poly_kalshi_scores[poly_kalshi_scores['max_score']>=0.98]

# %% [markdown]
# # 排除关闭的事件

# %%
poly_data_closed = poly_data[['question','closed']]
poly_data_closed.rename(columns={'question':'poly_question'},inplace=True)

# %%
remain_poly_kalshi=remain_poly_kalshi.merge(poly_data_closed,on='poly_question',how='left')

# %%
remain_poly_kalshi=remain_poly_kalshi[remain_poly_kalshi['closed']==True]

# %% [markdown]
# # 查看市场是否一致

# %%
# 获取 polymarket 上的市场
poly_data_token_outcome = poly_data[['question','token_outcome']]
poly_data_token_outcome.rename(columns={'question':'poly_question'}, inplace=True)

# %%
remain_poly_kalshi.merge(poly_data_token_outcome,on='poly_question',how='left')
# Out:
#     poly_index                                      poly_question  \
# 0      16474.0  Will Trump win 55% of voters without a college...
# 1      13503.0  Will there be a 269-269 tie in Electoral College?
# 2      17981.0                 AP calls Georgia by 8:00 AM Nov 6?
# 3       7736.0        Trump + Biden debate on June 27 as planned?
# 4      15405.0                     Will Trump win 5 swing states?
# 5      15298.0                     Will Trump win 2 swing states?
# 6      15090.0                     Will Trump win 7 swing states?
# 7      19024.0                 Coinbase #1 finance app on Friday?
# 8      15148.0                     Will Trump win 3 swing states?
# 9      15181.0                      Will Trump win 1 swing state?
# 10     15186.0                     Will Trump win 6 swing states?
# 11     15316.0                     Will Trump win 4 swing states?
# 12     15414.0                    Will Trump win no swing states?
# 13      9870.0                             Trump blowout victory?
# 14     17516.0                AP calls Michigan by 8:00 AM Nov 6?
# 15     15306.0        Will either FL, MN, NH, or TX flip in 2024?
# 16     16616.0  Will Trump do better with LGTBQ voters than in...
# 17      3617.0                 GTA 6 release date by end of year?
# 18     17989.0            AP calls Pennsylvania by 8:00 AM Nov 6?
# 19     16462.0    Will Trump do better with Latinos than in 2020?
# 20     19610.0                      SpaceX Starship launch today?
# 21     17667.0             Will Harris win Vermont by 32+ points?
# 22     17731.0              Will Trump win Wyoming by 50+ points?
# 23     16367.0     Will Trump do better with Asians than in 2020?
# 24     16215.0  Will Trump do better with men than in 2020 ele...
# 25     19048.0                     Coinbase top 10 app on Friday?
# 26      6322.0  Will there be a US government shutdown by Mar 23?
# 27      4906.0  Will there be a US government shutdown by Jan 20?
# 28      5371.0                   US government shutdown by Mar 9?
#
#                                      poly_question_id  kalshi_index  \
# 0   0x020acbf152845aa74ae0a7091e60a2f905dcb1f4e4c4...        1184.0
# 1   0x5d32895475ceb959a1981e97493af5a63216a0fdca96...         759.0
# 2   0x8be8f10c8f5661580967036cadbe624bcb5e5e9d16ec...        1237.0
# 3   0x5a6f8264e78442450e7152d10c23293dfbd0a37dcca9...        4756.0
# 4   0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 5   0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 6   0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 7   0x43d6ccf102b25516cd3eb9bd8da0b6c72c9bf4b0e241...        1030.0
# 8   0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 9   0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 10  0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 11  0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 12  0x1fbc4adde00c6f107af3c1b1770010c9d5f64ffd1277...         480.0
# 13  0xdc95b6e82ee75cadcb49454f32ee8e6aa509910b15c3...         502.0
# 14  0x0cf4f3731a2b51584a4b1278adeedbcef8ae355b09c3...        1236.0
# 15  0x5ee1e3054db390a671c7c47eb04fb11d24b2e13a995e...         481.0
# 16  0x9da662d30626fde1e2d617b4063e6f496abce58fe471...        1186.0
# 17  0x7419c97370a5faf09c4baf3e2ed24922ea1abcabedbe...         198.0
# 18  0xaf7465d0599630bb4f9c124acfcb313c046c9339003e...        1235.0
# 19  0x5fb17d809d2b5639a7a97e03f2a9d99c9290576a8116...        1187.0
# 20  0x6a75f9b80306d9602bf208ae60b8e629548865e17a71...        7606.0
# 21  0xf814e95de94538582a5807a5da7bc68e875f40af23fe...         461.0
# 22  0x0300a7314c1dc0a7f90746e52b208128c3f472c92d39...         470.0
# 23  0x5c3dd660f652492bc55604ccf5e06b12b58ced313978...        1188.0
# 24  0x4fd7a2529105c317a412e8e257d47d3cb5beb0e66097...        1185.0
# 25  0x4202fee649625ce59ca0f25295d549ccd7e1549b4d4a...        1029.0
# 26  0xfa52c347c336d0da5f839c0b3b0b9bb229dab57b966a...        7081.0
# 27  0xd44610cfe082e84a6094a8ce5d6105fa671aff3c0107...        7975.0
# 28  0x79c9b9c7b5fb646cf7df51d4c2d821dcdd580c1281d8...        7371.0
#
#                                          kalshi_title  \
# 0   Will Trump win more than 55% of voters without...
# 1      Will there be a 269-269 electoral college tie?
# 2              AP calls Georgia before 8:00 AM Nov 6?
# 3       Trump and Biden debate on June 27 as planned?
# 4               How many swing states will Trump win?
# 5               How many swing states will Trump win?
# 6               How many swing states will Trump win?
# 7      Will Coinbase be the #1 finance app on Friday?
# 8               How many swing states will Trump win?
# 9               How many swing states will Trump win?
# 10              How many swing states will Trump win?
# 11              How many swing states will Trump win?
# 12              How many swing states will Trump win?
# 13                             Trump blowout victory?
# 14            AP calls Michigan before 8:00 AM Nov 6?
# 15        Will any of FL, TX, MN, or NH flip in 2024?
# 16  Will Trump do better with LGTBQ voters than in...
# 17                                GTA 6 release date?
# 18        AP calls Pennsylvania before 8:00 AM Nov 6?
# 19    Will Trump do better with Latinos than in 2020?
# 20                            SpaceX Starship launch?
# 21    Will Harris win Vermont by more than 32 points?
# 22     Will Trump win Wyoming by more than 50 points?
# 23     Will Trump do better with Asians than in 2020?
# 24  Will Trump do better with men than in 2020 ele...
# 25           Will Coinbase be a top 10 app on Friday?
# 26               Government shutdown on Mar 23, 2024?
# 27               Government shutdown on Jan 20, 2024?
# 28                Government shutdown on Mar 4, 2024?
#
#          kalshi_event_ticker kalshi_series_ticker  max_score  closed  \
# 0                KXDJTNOGRAD          KXDJTNOGRAD   1.000000    True
# 1                 KXECTIE-24              KXECTIE   1.000000    True
# 2           KXELECTIONGACALL     KXELECTIONGACALL   1.000000    True
# 3       DEBATEHAPPEN-24JUN27       KXDEBATEHAPPEN   1.000000    True
# 4         KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 5         KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 6         KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 7   KXAPPRANKFINANCE-24NOV15     KXAPPRANKFINANCE   1.000000    True
# 8         KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 9         KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 10        KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 11        KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 12        KXSWINGSTATES24DJT   KXSWINGSTATES24DJT   1.000000    True
# 13           ECDJTBLOWOUT-24         ECDJTBLOWOUT   1.000000    True
# 14          KXELECTIONMICALL     KXELECTIONMICALL   1.000000    True
# 15             KXSWINGFLIP24        KXSWINGFLIP24   1.000000    True
# 16                 KXDJTLGBT            KXDJTLGBT   1.000000    True
# 17                      GTA6               KXGTA6   1.000000    True
# 18          KXELECTIONPACALL     KXELECTIONPACALL   1.000000    True
# 19               KXDJTLATINO          KXDJTLATINO   1.000000    True
# 20            SPACEXSTARSHIP     KXSPACEXSTARSHIP   1.000000    True
# 21          POPVOTEKHVT-2024          POPVOTEKHVT   1.000000    True
# 22         POPVOTEDJTWY-2024         POPVOTEDJTWY   1.000000    True
# 23                KXDJTASIAN           KXDJTASIAN   1.000000    True
# 24                  KXDJTMEN             KXDJTMEN   1.000000    True
# 25     KXAPPRANKFREE-24NOV15        KXAPPRANKFREE   1.000000    True
# 26           GOVSHUT-24MAR23            KXGOVSHUT   0.983739    True
# 27           GOVSHUT-24JAN20            KXGOVSHUT   0.983454    True
# 28           GOVSHUT-24MAR04            KXGOVSHUT   0.980816    True
#
#    token_outcome
# 0        Yes, No
# 1        Yes, No
# 2        Yes, No
# 3        Yes, No
# 4        Yes, No
# 5        Yes, No
# 6        Yes, No
# 7        Yes, No
# 8        Yes, No
# 9        Yes, No
# 10       Yes, No
# 11       Yes, No
# 12       Yes, No
# 13       Yes, No
# 14       Yes, No
# 15       Yes, No
# 16       Yes, No
# 17       Yes, No
# 18       Yes, No
# 19       Yes, No
# 20       Yes, No
# 21       Yes, No
# 22       Yes, No
# 23       Yes, No
# 24       Yes, No
# 25       Yes, No
# 26       Yes, No
# 27       Yes, No
# 28       Yes, No
